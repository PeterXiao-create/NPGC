# %%
import pandas as pd
import csv

# %%
import csv

# Total Fixed Supply: 1,000,000,000
header = ['Category', 'Total Supply', 'Available at Launch', 'Cliff Period']
data = [['Genesis Drop', '30%', '0%', '3 months'],
       ['Community Pool (Locked-on-chain)', '20%', '20%', '0 months'],
       ['Core Development', '20%', '0%', '6 months'],
       ['Core Team ', '10%', '0%', '6 months'],
       ['Private Sale', '10%', '0%', '6 months'],
       ['Future Development Plan', '10%', '0%', '24 months']]



with open('NPGC_token_allocation.csv', 'w', encoding='UTF8', newline='') as f:
    writer = csv.writer(f)

    # write the header
    writer.writerow(header)

    # write multiple rows
    writer.writerows(data)

# %%
df = pd.read_csv('./NPGC_token_allocation.csv')

# %%
df
# Out:
#                            Category Total Supply Available at Launch  \
# 0                      Genesis Drop          30%                  0%
# 1  Community Pool (Locked-on-chain)          20%                 20%
# 2                  Core Development          20%                  0%
# 3                        Core Team           10%                  0%
# 4                      Private Sale          10%                  0%
# 5           Future Development Plan          10%                  0%
#
#   Cliff Period
# 0     3 months
# 1     0 months
# 2     6 months
# 3     6 months
# 4     6 months
# 5    24 months

# %%
header = ['Category', 'Sub-Category', 'Total Supply', 'Available at Launch', 'Cliff Period']
rows = [
    {'Category': 'Genesis Drop',
     'Sub-Category': 'Community Airdrop',
    'Total Supply': '10%',
    'Available at Launch': '0%',
    'Cliff Period': '3 months'},
    {'Category': 'Genesis Drop',
     'Sub-Category': 'Non-Profit-Organizations Airdrop',
    'Total Supply': '10%',
    'Available at Launch': '0%',
    'Cliff Period': '3 months'},
    {'Category': 'Genesis Drop',
     'Sub-Category': 'Strategic Reserve',
    'Total Supply': '10%',
    'Available at Launch': '0%',
    'Cliff Period': '3 months'},
    {'Category': 'Community Pool',
     'Sub-Category': 'Providing Liquidity (Locked-on-chain)',
    'Total Supply': '20%',
    'Available at Launch': '20%',
    'Cliff Period': '3 months'},
    {'Category': 'Blockchain Eco-System Development',
     'Sub-Category': 'Econ-System Incentive',
    'Total Supply': '10%',
    'Available at Launch': '0%',
    'Cliff Period': '6 months'},
    {'Category': 'Blockchain Eco-System Development',
     'Sub-Category': 'Marketing',
    'Total Supply': '3%',
    'Available at Launch': '0%',
    'Cliff Period': '6 months'},
    {'Category': 'Blockchain Eco-System Development',
     'Sub-Category': 'Non-Profit Grants',
    'Total Supply': '5%',
    'Available at Launch': '0%',
    'Cliff Period': '6 months'},
    {'Category': 'Blockchain Eco-System Development',
     'Sub-Category': 'DAPP Emergency Fund',
    'Total Supply': '2%',
    'Available at Launch': '0%',
    'Cliff Period': '6 months'},
    {'Category': 'Core Team',
     'Sub-Category': 'Core Dev-compensation',
    'Total Supply': '4%',
    'Available at Launch': '0%',
    'Cliff Period': '6 months'},
    {'Category': 'Core Team',
     'Sub-Category': 'Core Dev-Future recuite',
    'Total Supply': '6%',
    'Available at Launch': '0%',
    'Cliff Period': '12 months'},
    {'Category': 'Private Sale',
     'Sub-Category': 'Seed Round',
    'Total Supply': '2%',
    'Available at Launch': '0%',
    'Cliff Period': '6 months'},
    {'Category': 'Private Sale',
     'Sub-Category': 'Early Stage',
    'Total Supply': '2%',
    'Available at Launch': '0%',
    'Cliff Period': '6 months'},
    {'Category': 'Private Sale',
     'Sub-Category': 'Expansion Stage',
    'Total Supply': '3%',
    'Available at Launch': '0%',
    'Cliff Period': '6 months'},
    {'Category': 'Private Sale',
     'Sub-Category': 'Late Stage',
    'Total Supply': '3%',
    'Available at Launch': '0%',
    'Cliff Period': '6 months'},
    {'Category': 'Future Development Plan',
     'Sub-Category': 'Non-Profit Partnership',
    'Total Supply': '5%',
    'Available at Launch': '0%',
    'Cliff Period': '12 months'},
    {'Category': 'Future Development Plan',
     'Sub-Category': 'New Innovation',
    'Total Supply': '5%',
    'Available at Launch': '0%',
    'Cliff Period': '24 months'}
]
with open('NPGC_token_allocation_3.csv','w', encoding='UTF8', newline='') as f:
    writer = csv.DictWriter(f, fieldnames=header)
    writer.writeheader()
    writer.writerows(rows)

# %%
df = pd.read_csv('./NPGC_token_allocation_3.csv')
df
# Out:
#                              Category                           Sub-Category  \
# 0                        Genesis Drop                      Community Airdrop
# 1                        Genesis Drop       Non-Profit-Organizations Airdrop
# 2                        Genesis Drop                      Strategic Reserve
# 3                      Community Pool  Providing Liquidity (Locked-on-chain)
# 4   Blockchain Eco-System Development                  Econ-System Incentive
# 5   Blockchain Eco-System Development                              Marketing
# 6   Blockchain Eco-System Development                      Non-Profit Grants
# 7   Blockchain Eco-System Development                    DAPP Emergency Fund
# 8                           Core Team                  Core Dev-compensation
# 9                           Core Team                Core Dev-Future recuite
# 10                       Private Sale                             Seed Round
# ...

# %%
def p2f(x):
    return float(x.strip('%'))/100

# %%
df['Total Supply']=df['Total Supply'].str.rstrip("%").astype(float)/100

# %%
df
# Out:
#                              Category                           Sub-Category  \
# 0                        Genesis Drop                      Community Airdrop
# 1                        Genesis Drop       Non-Profit-Organizations Airdrop
# 2                        Genesis Drop                      Strategic Reserve
# 3                      Community Pool  Providing Liquidity (Locked-on-chain)
# 4   Blockchain Eco-System Development                  Econ-System Incentive
# 5   Blockchain Eco-System Development                              Marketing
# 6   Blockchain Eco-System Development                      Non-Profit Grants
# 7   Blockchain Eco-System Development                    DAPP Emergency Fund
# 8                           Core Team                  Core Dev-compensation
# 9                           Core Team                Core Dev-Future recuite
# 10                       Private Sale                             Seed Round
# ...

# %%
total=df['Total Supply'].sum()
print(total)
# Out:
# 1.0
